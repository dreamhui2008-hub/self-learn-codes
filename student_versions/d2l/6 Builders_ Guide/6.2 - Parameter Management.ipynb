# %%
# PyTorch functions/methods helpers

#6.2.1
for name, param in net.named_parameters(): # Give me every learnable parameter in this network, along with its name
    print(f"{name:10s}", shape(param), "scalars=", param.numel()) # numel() gives the number of elements inside a param, e.g. shape of (6, 4) has 24 number of elements

#6.2.2
state = net.state_dict() # Give me the names and tensors that make up the model's saved state (e.g. shapes of weights and bias)

#6.2.3
assert torch.isfinite(shared.weight.grad).all() # Check if shared.weight.grad contains only valid numbers, all() by default checks if a list only contains True (so check isfinite() True or False, then pass all())

#6.2.4
for param in model[0].parameters():
    param.requires_grad_(False) # requires_grad_() can be called as a method onto a param

trainable = [(name, shape(p)) for name, p in model.named_parameters() if p.requires_grad] # `p` is the actual Parameter/tensor object, not just information about it, hence we can inspect its requires_grad property

#6.2.5
self.weight = nn.Parameter(torch.randn(3, 1)) # does not need requires_grad = True since nn.Parameter() automatically assumes grad

# %% [markdown]
# * Chapter 6.1 established that modules are the boundaries of model code. Chapter 6.2 asks what those boundaries own.
#
# * In deep learning, the learned behavior of a model lives in its parameters, so serious model work requires being able to find them, name them, count them, share them intentionally, freeze them intentionally, and detect when they were never registered at all.

# %% [markdown]
# # How to use this notebook

# %% [markdown]
# * Run the notebook from top to bottom.
#
# * Every code block is designed to be cloud-runnable and self-contained inside this notebook.
#
# * The drills are intentionally small: predict the shape or behavior first, run the cell, then read the assertion as the contract you must understand.

# %% [markdown]
# # You are done when you can

# %% [markdown]
# - explain why parameters are model state rather than temporary forward-pass values
# - inspect parameter names, shapes, and scalar counts
# - connect parameter names to the module tree that owns them
# - explain how tied parameters differ from copied parameters
# - show that optimizers only update parameters they receive
# - catch an unregistered tensor mistake

# %%
import math
from pathlib import Path
import tempfile

import torch
from torch import nn

torch.manual_seed(0)
torch.set_printoptions(precision=4, sci_mode=False)

def shape(x):
    return tuple(x.shape)

def count_scalars(parameters):
    return sum(p.numel() for p in parameters)

# %% [markdown]
# # 6.2.0 The Problem This Notebook Solves

# %% [markdown]
# After you can write modules, the next question is ownership.
#
# A neural network is not only a forward computation. It is also a collection of learned tensors. During training, the optimizer needs a reliable answer to a simple question:
#
# ```text
# which tensors should I update?
# ```

# %% [markdown]
# PyTorch answers that question through module registration.
#
# * If a trainable tensor is stored correctly inside a module, it appears in `parameters()` and `named_parameters()`.
#
# * If it is hidden inside an ordinary list, created only inside `forward`, or stored as a plain tensor when it should be a parameter, PyTorch may not find it.

# %% [markdown]
# This is why parameter management is theoretical and mechanical at the same time:
#
# - The theory says the model's learned function is encoded in parameters.
# - The software says those parameters must be discoverable by the module tree.
# - The optimizer says it can only update tensors it was given.
# - The debugger says names and shapes are how you locate the source of a mistake.
#
# The handoff from 6.1 is direct: modules define ownership boundaries; parameter management inspects what the boundaries actually own.

# %% [markdown]
# # 6.2.1 Parameters Live Inside a Module Tree

# %% [markdown]
# When a model is nested, parameter names become paths through the module tree. In a `Sequential`, numeric names such as `0.weight` and `3.0.weight` are not arbitrary. They tell you where the parameter lives.
#
# The conceptual point is that a large model is not a bag of unnamed arrays. It is a hierarchy of components, and each trainable tensor has a location in that hierarchy. This matters when you:
#
# - debug a layer that has the wrong shape
# - freeze only part of a model
# - initialize only certain layer types
# - give different optimizer settings to different parameter groups
# - compare model sizes

# %% [markdown]
# Before running the cell, predict the scalar count:
#
# ```text
# Linear(4, 6): weight 6 by 4, bias 6
# Linear(6, 3): weight 3 by 6, bias 3
# Linear(3, 1): weight 1 by 3, bias 1
# ```
#
# The code prints both tensor shapes and scalar counts because both are useful.
#
# A single weight matrix is one parameter tensor, but it can contain many scalar values.

# %%
net = nn.Sequential(
    nn.Linear(4, 6),
    nn.ReLU(),
    nn.Sequential(
        nn.Linear(6, 3),
        nn.ReLU(),
    ),
    nn.Linear(3, 1),
)

for name, param in net.named_parameters(): # Give me every learnable parameter in this network, along with its name
    print(f"{name:10s}", shape(param), "scalars=", param.numel()) # numel() gives the number of elements inside a param, e.g. shape of (6, 4) has 24 number of elements

total = count_scalars(net.parameters())
print("total trainable scalars", total)

assert total == (6*4 + 6) + (3*6 + 3) + (1*3 + 1)
# Out:
# 0.weight   (6, 4) scalars= 24
# 0.bias     (6,) scalars= 6
# 2.0.weight (3, 6) scalars= 18
# 2.0.bias   (3,) scalars= 3
# 3.weight   (1, 3) scalars= 3
# 3.bias     (1,) scalars= 1
# total trainable scalars 55

# %% [markdown]
# # 6.2.2 `state_dict` Is Saved Tensor State, Not Just Trainable Parameters

# %% [markdown]
# For a simple MLP, those two lists look the same because the model only has trainable weights and biases.
# * `named_parameters()` answers "what trainable tensors does this model expose?
# * `state_dict()` answers a broader save/load question: "what tensor state would I need to serialize to recreate this model's current behavior?"
#
#
#
# Later, they can differ.
# *   Batch normalization, for example, has learned parameters but also running mean and variance buffers.
# *   Those buffers affect inference even though they are not usually updated by gradients.

# %% [markdown]
# The theoretical distinction is:
#
# - parameters are **learned by optimization**
# - buffers are **persistent model state**
# - both can affect the model's output
#
# This section prepares the handoff to Chapter 6.6, where saving and loading depends on understanding `state_dict`.

# %%
state = net.state_dict()
print("state_dict keys:")

for key, value in state.items():
    print(f"{key:10s}", shape(value))

parameter_names = [name for name, _ in net.named_parameters()]
state_names = list(state.keys())

assert parameter_names == state_names
# Out:
# state_dict keys:
# 0.weight   (6, 4)
# 0.bias     (6,)
# 2.0.weight (3, 6)
# 2.0.bias   (3,)
# 3.weight   (1, 3)
# 3.bias     (1,)

# %% [markdown]
# # 6.2.3 Tied Parameters Share One Object

# %% [markdown]
# Parameter sharing is an architectural claim, not just a memory trick.
#
# * If two parts of a model use equal copied weights, they start with the same values but can drift apart during training.
#
# * If they use the same parameter object, there is only one learned tensor.
#
# * **Every use contributes gradient to that same tensor, and every optimizer step updates the one shared object**.

# %% [markdown]
# This matters in real models. Weight tying can express a belief like:
#
# ```text
# these two computations should use the same learned rule
# ```
#
# The most important mechanical test is object identity, not value equality.
# * `a == b` asks whether values match.
# * `a is b` asks whether both names point to the exact same object.

# %% [markdown]
# ## Parameter sharing
#
# You can have both parts use the **same parameter object**:
#
# ```text
#              ┌── Layer A ──┐
# shared W ────┤             ├──→
#              └── Layer B ──┘
# ```
#
# Now there's literally only **one `W`**.
#
# If Layer A and Layer B both use it, their gradients both contribute to updating that same `W`.
#
# Conceptually:
#
# ```text
#                     gradient from A
#                          ↓
#                        ┌───┐
# Layer A ──────────────→│ W │←────────────── Layer B
#                        └───┘
#                          ↑
#                     gradient from B
# ```
#
# Then the optimizer updates **one tensor**.
#
# ---
#
# ## Why would you want that?
#
# Because you're telling the model an architectural fact:
#
# > **"These two parts should learn the same transformation."**
#
# This can be useful when the same operation should be applied repeatedly or symmetrically.
#
# ### Example: Convolutional neural networks
#
# A convolution filter is reused across many different locations of an image. You don't want a completely separate filter for every pixel location.
#
# Instead:
#
# ```text
# same filter
#     ↓
# location 1
# location 2
# location 3
# location 4
# ...
# ```
#
# The filter learns something like:
#
# > **"Detect this pattern wherever it appears."**
#
# That's **parameter sharing**.
#
# ### Example: Siamese networks
#
# The same network processes two inputs:
#
# ```text
# Image A ──→ SAME NETWORK ──→ representation A
#                          ↑
# Image B ──→ SAME NETWORK ──→ representation B
# ```
#
# You want both images to be processed using the **same learned transformation**, so their representations are comparable.
#
# ---
#
# ## The key distinction
#
# This is the part your homework is emphasizing.
#
# ### Copied weights
#
# ```text
# W1 = W2 initially
# ```
#
# means:
#
# > **"Start with the same values."**
#
# But after training:
#
# ```text
# W1 ≠ W2
# ```
#
# can happen.
#
# ### Shared parameter
#
# ```text
# W1 is W2
# ```
#
# means:
#
# > **"There is only one weight. Both parts of the network use it."**
#
# So parameter sharing isn't primarily about saving memory. **It's a way of imposing structure on what the model is allowed to learn.**

# %% [markdown]
# Before running the cell, predict:
#
# - The shared layer should appear only once in `named_parameters()`.
# - The two positions in the model should point to the same weight object.
# - The shared weight should receive a gradient after backward.

# %%
shared = nn.Linear(2, 2, bias=False)
tied_net = nn.Sequential(shared, nn.ReLU(), shared)

print("same weight object:", tied_net[0].weight is tied_net[2].weight) # Yes, because the sequence is 1) shared, 2) ReLU, 3) shared, so 1) = 3)
print("named parameters:", [name for name, _ in tied_net.named_parameters()])

X = torch.ones(1, 2)
loss = tied_net(X).sum()
loss.backward()

print("shared gradient:")
print(shared.weight.grad)

assert tied_net[0].weight is tied_net[2].weight
assert shared.weight.grad is not None # Confirms that the parameter actually participated (since its shared in 2 layers) in the computation and received a gradient
assert torch.isfinite(shared.weight.grad).all() # Check if shared.weight.grad contains only valid numbers, all() by default checks if a list only contains True (so check isfinite() True or False, then pass all())
# Out:
# same weight object: True
# named parameters: ['0.weight']
# shared gradient:
# tensor([[0., 0.],
#         [0., 0.]])

# %% [markdown]
# # 6.2.4 Freezing Means `requires_grad=False`

# %% [markdown]
# Freezing is the opposite of learning for a selected part of the model.
#
# * The frozen tensor still participates in the forward pass, so it **still affects predictions**.
#
# * The difference is that **autograd does not compute gradients for it**, and the **optimizer should not update it**.

# %% [markdown]
# This is useful when:
#
# - using a pretrained feature extractor
# - training only a new classification head
# - comparing what happens when part of a model is held fixed
# - preventing a stable component from being disturbed
#
# The theory-level distinction is important:
#
# ```text
# frozen does not mean removed
# frozen means used in forward computation but not adapted by gradient descent
# ```

# %% [markdown]
# The cell freezes the first linear layer. The final linear layer remains trainable, so its gradient should exist after backward.

# %%
model = nn.Sequential(nn.Linear(3, 4), nn.ReLU(), nn.Linear(4, 1))

for param in model[0].parameters(): # Opted out requires grad, or does not require grad, for the first layer (3, 4)
    param.requires_grad_(False) # requires_grad_() can be called as a method onto a param

trainable = [(name, shape(p)) for name, p in model.named_parameters() if p.requires_grad] # `p` is the actual Parameter/tensor object, not just information about it, hence we can inspect its requires_grad property
frozen = [(name, shape(p)) for name, p in model.named_parameters() if not p.requires_grad]

optimizer = torch.optim.SGD((p for p in model.parameters() if p.requires_grad), lr=0.01) # Only train params that require grad

X = torch.randn(5, 3)
y = torch.randn(5, 1)
loss = ((model(X) - y) ** 2).mean()
optimizer.zero_grad()
loss.backward()

assert model[0].weight.grad is None # True, since it was established at the beginning that first layer does not require grad
assert model[2].weight.grad is not None

# %% [markdown]
# # 6.2.5 Break It Deliberately: Plain Tensor Is Not Registered

# %% [markdown]
# This failure is subtle because the forward computation can look mathematically valid.
#
# * The layer has a tensor called `weight`, and that tensor even has `requires_grad=True`.
#
# * But PyTorch's module machinery does not treat every tensor attribute as a registered parameter.
#
# * For optimizers and save/load tools to discover a trainable tensor, it should be an `nn.Parameter` assigned to `self`. That assignment is the registration event.

# %% [markdown]
# The conceptual mistake is ownership ambiguity. The code creates a tensor, but it does not clearly tell PyTorch:
#
# ```text
# this tensor is part of the learned model state
# ```
#
# That is why the optimizer rejects the model. It sees no registered parameters to update.

# %%
class BadLinear(nn.Module):

  def __init__(self):
    super().__init__()
    self.weight = torch.randn(3, 1, requires_grad=True) # should wrap this inside nn.Parameter() so PyTorch knows that this is a learnable param
    # self.weight = nn.Parameter(torch.randn(3, 1)) # does not need requires_grad = True since nn.Parameter() automatically assumes grad

  def forward(self, X):
    return X @ self.weight

bad = BadLinear()
print("named parameters:", list(bad.named_parameters()))

try:
  torch.optim.SGD(bad.parameters(), lr=0.1)
except ValueError as err:
  print(type(err).__name__)
  print(str(err))
else:
  raise AssertionError("An optimizer should reject an empty parameter list.")
# Out:
# named parameters: [('weight', Parameter containing:
# tensor([[ 0.4520],
#         [-0.9759],
#         [ 0.7112]], requires_grad=True))]
# optimizer created successfully!

# %% [markdown]
# # 6.2 Checkpoint

# %% [markdown]
# Answer these before moving on.
#
# You do not need a separate notes file for chapters; short answers in markdown cells or in your own study notes are enough.
#
# 1. Why is parameter ownership a module-tree question rather than only a tensor question?
# > Because PyTorch tracks parameters based on which `nn.Module` owns/registers them. A tensor having `requires_grad=True` alone does not make it a model parameter
#
# 2. What is the difference between counting parameter tensors and counting scalar parameter values?
# > * Counting parameter tensors tells you how many separate parameter objects the model has. Counting scalar parameter values tells you how many individual numbers are contained across those tensors
# > * Modern ML usually uses "number of parameters" to mean the total number of scalar values
#
# 3. Why can `state_dict()` include tensor state beyond trainable parameters in larger models?
# > * `state_dict()` contains the tensors needed to save and restore a module's state, which can include both parameters and persistent buffers
# > * Some of these tensors aren't trainable parameters
#
# 4. Why does a tied layer appear once in `named_parameters()` even if it is used twice?
# > Because both uses refer to the same parameter object, PyTorch registers that parameter only once rather than treating it as two separate parameters
#
# 5. Why is object identity more important than value equality for tied parameters?
# > * Object identity tells us whether two references point to the exact same parameter object
# > * Two separate parameters can have equal values, but they can still receive different gradients and update independently.
#
# 6. What exactly changes when a parameter is frozen?
# > Whether `requires_grad` is activated or not
#
# 7. Why did `BadLinear` have no registered parameters?
# > Because the tensor `self.weight` was not registered with PyTorch (e.g. needs `nn.Parameter()`)
