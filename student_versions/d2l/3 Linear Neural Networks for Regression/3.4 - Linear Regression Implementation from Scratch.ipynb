# %% [markdown]
# *   This notebook implements linear regression training directly with tensors.
# *    The goal is to see every moving part before using concise framework shortcuts.

# %%
import math
import random
import numpy as np
import torch

# %%
def data_iter(X, y, batch_size): # Refer to 3.3 - Synthetic Regression Data for this function

  indices = list(range(len(X)))
  random.shuffle(indices)

  for start in range(0, len(y), batch_size):
    idx = indices[start:start+batch_size]
    yield X[idx], y[idx]

# %% [markdown]
# # 3.4.1 Defining the Model

# %% [markdown]
# ## 1. Intuition

# %% [markdown]
# *   Defining the model means writing the function that maps input features to predictions.
# *   For linear regression, the model is a weighted sum plus a bias: `X @ w + b`.

# %% [markdown]
# ## 2. Why this exists

# %% [markdown]
# *   Training cannot begin until the model's forward computation is clear. The forward computation is the path from inputs to predictions.

# %% [markdown]
# ## 3. Examples

# %% [markdown]
# *   Manual Python prediction for one example.

# %%
x = [1.0, 2.0]
w = [0.1, -0.2]
b = 0.0
pred = x[0] * w[0] + x[1] * w[1] + b # 1*0.1 + 2*-0.2 + 0 = 0.1 - 0.4 = -0.3
pred
# Out:
# -0.30000000000000004

# %% [markdown]
# *   Tensor function for a batch of examples.

# %%
def linreg(X, w, b):
  return X @ w + b

X = torch.tensor([[1.0, 2.0], [3.0, 4.0]])
w = torch.tensor([0.1, -0.2])
b = torch.tensor(0.0) # Python will broadcast this into [0.0, 0.0] to compute against [-0.3, -0.5]
linreg(X, w, b) # Goes through 1*0.1 + 2*-0.2 + 0 = -0.3 first, then 3*0.1 + 4*-0.2 + 0 = -0.5
# Out:
# tensor([-0.3000, -0.5000])

# %% [markdown]
# ## 4. Step-by-step breakdown

# %% [markdown]
# *   The manual code computes one weighted sum.
# *   `linreg` generalizes the same formula to a batch.
# *   `X @ w` gives one prediction per row of `X`.
# *   `+ b` broadcasts the scalar bias to every prediction.

# %% [markdown]
# ## 5. Connection to ML systems

# %% [markdown]
# *   This model function is the from-scratch version of what `torch.nn.Linear` will later do internally.

# %% [markdown]
# ## 6. Common confusion points

# %% [markdown]
# - The model function should not compute loss.
# - Weights must match the number of input features.
# - The output shape should match the label shape.
# - Initialization values are not learned yet; they are just starting points.

# %% [markdown]
# # 3.4.2 Defining the Loss Function

# %% [markdown]
# ## 1. Intuition

# %% [markdown]
# *   A loss function compares predictions with labels and returns a number representing error.
# *   Squared loss is `(prediction - label)^2`, often averaged across a batch.

# %% [markdown]
# ## 2. Why this exists

# %% [markdown]
# *   The loss defines what training tries to reduce. Different losses mean different learning goals.

# %% [markdown]
# ## 3. Examples

# %% [markdown]
# *   Manual squared loss for two predictions.

# %%
preds = [1.0, 3.0]
labels = [2.0, 1.0]
losses = [(preds[i] - labels[i]) ** 2 for i in range(2)]
# Calculates (1-2)**2 = 1 first, then (3-1)**2 = 4

sum(losses) / len(losses) # (1+4)/2 = 2.5
# Out:
# 2.5

# %% [markdown]
# *   Tensor squared loss.

# %%
def squared_loss(y_hat, y):
  return (y_hat - y) ** 2 / 2

y_hat = torch.tensor([1.0, 3.0])
y = torch.tensor([2.0, 1.0])
squared_loss(y_hat, y)
# Calculates (1-2)**2 / 2 = 0.5 first, then (3-1)**2 /2 = 2
# Out:
# tensor([0.5000, 2.0000])

# %% [markdown]
# ## 4. Step-by-step breakdown

# %% [markdown]
# *   The manual version computes one squared error per example.
#
# *   [**The tensor version returns per-example losses.**]
#
# *   The division by 2 is a convenience because it cancels a factor of 2 when differentiating the square.
#
# *   A training loop usually reduces these losses with `.mean()` or `.sum()`
# > *   We need to reduce in order to generate one scalar loss from a list (vector) of losses to update the params.
# > *   There are training methods that retain and update regional/batch loss separately, with SGD being one example (although some still prefer to average the per batch loss for a global loss).
# > * Other examples include the following:
# >> * Multi-task learning, where different output heads have different losses.
# >> * MoEs, where only some parameters are active for a given input.
# >> * Auxiliary losses, where intermediate layers have their own objectives.
# >> * Layer-wise training methods, though these are less common today.

# %% [markdown]
# ## 5. Connection to ML systems

# %% [markdown]
# *   PyTorch loss modules often combine per-example computation and reduction.
# *   Writing it manually first makes the reduction choice visible.

# %% [markdown]
# ## 6. Common confusion points

# %% [markdown]
# - Per-example losses are not the same as one scalar loss.
# - Dividing by 2 changes scale, not the location of the minimum.
# - The loss function should compare aligned predictions and labels.
# - Shape mismatch can accidentally trigger broadcasting.

# %% [markdown]
# # 3.4.3 Defining the Optimization Algorithm

# %% [markdown]
# ## 1. Intuition

# %% [markdown]
# *   An optimization algorithm updates parameters to reduce loss.
# *   Stochastic gradient descent, or SGD, updates each parameter by moving it opposite its gradient.
# *   A gradient is the slope of the loss with respect to a parameter.

# %% [markdown]
# ## 2. Why this exists

# %% [markdown]
# *   The model learns only when parameters change.
# *   Gradients tell us direction. The learning rate controls step size.

# %% [markdown]
# ## 3. Examples

# %% [markdown]
# *   Manual SGD update for one scalar parameter.

# %%
w = 3.0
grad = 4.0
lr = 0.1
new_w = w - lr * grad # 3 - 0.1*4 = 2.6
new_w
# Out:
# 2.6

# %% [markdown]
# *   Tensor SGD update for a list of parameters.
# *   Notice how the loss here is a sum from all the batches, and the average loss is computed based on total / batch size.
# *   In reality, PyTorch would calculate the average loss over batches as it goes like this:
#     ```
#     criterion = nn.CrossEntropyLoss()   # reduction='mean' by default
#     loss = criterion(pred, target)
#     ```

# %%
def sgd(params, lr, batch_size):
 # Disable gradient tracking while updating the parameters.
 # Otherwise, PyTorch would record these updates in the computation graph.
 with torch.no_grad():
  for p in params:
    # Gradient descent update.
    # If the loss was summed over the batch (like SGD), divide by batch_size to use the average gradient
    p -= lr * p.grad / batch_size

    # Clear accumulated gradients before the next backward pass (PyTorch adds gradients to .grad by default).
    p.grad.zero_()

# %% [markdown]
# ## 4. Step-by-step breakdown

# %% [markdown]
# *   `new_w = w - lr * grad` moves the parameter opposite the gradient.
#
# *   `with torch.no_grad()` prevents PyTorch from tracking the update itself.
#
# *   The loop visits each parameter tensor.
#
# *   `p.grad.zero_()` clears old gradients so the next backward pass starts fresh.
#
# *   Dividing by `batch_size` keeps update scale consistent when the loss was summed.

# %% [markdown]
# ## 5. Connection to ML systems

# %% [markdown]
# *   Framework optimizers automate this same pattern.
# *   They store parameter references and update them after `backward()` computes gradients.
#
# *   Instead of writing your own `sgd()` function, PyTorch provides optimizer classes like
#
#     ```python
#     optimizer = torch.optim.SGD(model.parameters(), lr=0.1)
#     ```
#
# *   When you create the optimizer, it **stores references to the model's parameters**:
#
#     ```text
#     optimizer
#         ├── weight1
#         ├── bias1
#         ├── weight2
#         └── bias2
#     ```
#
# *   It doesn't make copies. It simply remembers, "these are the tensors I'm responsible for updating."

# %% [markdown]
# ## 6. Common confusion points

# %% [markdown]
# - Optimizers update parameters, not predictions directly.
# - Learning rate too large can make training unstable.
# - Gradients accumulate unless cleared.
# - Parameter updates should usually happen inside `torch.no_grad()`.

# %% [markdown]
# # 3.4.4 Training

# %% [markdown]
# ## 1. Intuition

# %% [markdown]
# *   Training repeats a sequence:
# > *   get a batch,
# > *   predict,
# > *   compute loss,
# > *   compute gradients,
# > *   update parameters.
# *   What changes each iteration are the parameter values and the current batch.

# %% [markdown]
# ## 2. Why this exists

# %% [markdown]
# *   The training loop turns model definition, loss, and optimization into learning. Without the loop, the pieces do not improve.

# %% [markdown]
# ## 3. Examples

# %% [markdown]
# *   A compact from-scratch training loop on synthetic data.

# %%
def data_iter(X, y, batch_size): # Refer to 3.3 - Synthetic Regression Data for this function

  indices = list(range(len(X)))
  random.shuffle(indices)

  for start in range(0, len(y), batch_size):
    idx = indices[start:start+batch_size]
    yield X[idx], y[idx]

def linreg(X, w, b):
  return X @ w + b

def squared_loss(y_hat, y):
  return (y_hat - y) ** 2 / 2

def sgd(params, lr, batch_size):
 with torch.no_grad():
  for p in params:
    p -= lr * p.grad / batch_size
    p.grad.zero_()

# %%
X = torch.randn(20, 2)
y = X @ torch.tensor([2.0, -3.4]) + 4.2 + torch.randn(20) * 0.01
w = torch.randn(2, requires_grad=True) # Initiate random weights
b = torch.zeros(1, requires_grad=True) # Initiate bias from 0

for epoch in range(3):
  for batch_X, batch_y in data_iter(X, y, 5):

    # 1 calculate lingreg(batch_X, w, b), which is equivalent to the calculation for y;
    # 2 perform square_loss that calculates the loss from linreg to that of y;
    # 3 sum the loss within the current batch (e.g. examples 1-5 for a batch size of 5)
    loss = squared_loss(linreg(batch_X, w, b), batch_y).sum()

    # 4 compute the gradients of the current batch loss with respect to w and b via autograd (chain-rule)
    loss.backward()

    # 5 update w and b via sgd (divide the gradients by batch size or average gradient)
    sgd([w, b], lr=0.03, batch_size=5)

w,b
# Out:
# (tensor([ 0.2106, -0.9585], requires_grad=True),
#  tensor([1.4237], requires_grad=True))

# %% [markdown]
# ## 4. Step-by-step breakdown

# %% [markdown]
# *   The true parameters create synthetic labels.
#
# *   `w` and `b` are learnable parameters because they have `requires_grad=True`.
#
# *   The outer loop repeats epochs.
#
# *   The inner loop reads one minibatch at a time.
#
# *   For each minibatch, the code computes loss, calls `backward()`, and updates parameters with SGD.

# %% [markdown]
# ## 5. Connection to ML systems

# %% [markdown]
# *   This is the essential PyTorch training loop without optimizer classes or module abstractions.
# *   Later concise code compresses the same sequence.

# %% [markdown]
# ## 6. Common confusion points

# %% [markdown]
# - `backward()` must happen before the SGD update.
# - Gradients must be cleared after each update.
# - The current batch changes inside the inner loop.
# > * Every time the inner loop runs, `batch_X` and `batch_y` are different.
# - Learned parameters should move toward true parameters on this synthetic task, but noise prevents exact equality.
# > * Remember `y = X @ torch.tensor([2.0, -3.4]) + 4.2 + torch.randn(20) * 0.01`?
# > * The last `randn()` function is the noise for overfit control (so that the model generalize instead of memorize)
# > * Our training aims to bring w and b as close to `[2.0, -3.4]` and `4.2` as possible.

# %% [markdown]
# # 3.4.5 Summary

# %% [markdown]
# ## 1. Intuition

# %% [markdown]
# *   From-scratch linear regression has four core parts: model, loss, optimizer, and training loop.

# %% [markdown]
# ## 2. Why this exists

# %% [markdown]
# *   Writing these parts manually builds the mental model needed to understand framework abstractions.

# %% [markdown]
# ## 3. Examples

# %% [markdown]
# *   The training sequence as explicit names.

# %%
steps = [
    "read batch",
    "predict",
    "compute loss",
    "backward",
    "update parameters",
]

# %% [markdown]
# ## 4. Step-by-step breakdown

# %% [markdown]
# *   The list records the order of operations.
#
# *   Every training iteration follows this order.
#
# *   If the order changes accidentally, training may fail or silently behave incorrectly.

# %% [markdown]
# ## 5. Connection to ML systems

# %% [markdown]
# *   Most deep learning systems are variations of this same sequence, even when wrapped in classes and library calls.

# %% [markdown]
# ## 6. Common confusion points

# %% [markdown]
# - A clear training loop is more important than a clever one.
# - Loss scale affects gradient scale, which affects how much your params update.
# > * Training with small steps (lr) with small loss at a time can be more stable, but also more time consuming.
# > * Model training involves balancing accuracy, efficiency, and computational cost.
# - Parameter initialization affects the starting point.
# > * Poor initialization can cause slow learning, vanishing gradients, exploding gradients, or symmetry problems.
# > * For linear regression, initialization usually isn't a huge issue because the loss surface is convex.
# > * For deep neural networks (millions of params with layers of bias & weights), initialization is much more important (since the loss surface can sometimes be flat, sometimes steep, sometimes saddle...).
# - Debug from-scratch code with tiny synthetic data first.

# %% [markdown]
# # 3.4.6 Exercises

# %% [markdown]
# ## 1. Intuition

# %% [markdown]
# *   These exercises make you inspect and modify the training loop.

# %% [markdown]
# ## 2. Why this exists

# %% [markdown]
# *   Small changes reveal which parts of training control speed, stability, and correctness.

# %% [markdown]
# ## 3. Examples

# %% [markdown]
# *   Exercise 1: run one prediction with current parameters.

# %%
sample_X = torch.tensor([1.0, 2.0])
linreg(sample_X, w.detach(), b.detach()) # Inherit the tensors of w and b from earlier in the notebook, but requires_grad = False (detach from PyTorch's computational graph)
# Out:
# tensor([-0.2827])

# %% [markdown]
# *   Exercise 2: compute one batch loss without updating.

# %%
batch_X, batch_y = next(data_iter(X, y, 5))
y_hat = linreg(batch_X, w.detach(), b.detach())
squared_loss(y_hat, batch_y).mean()
# Out:
# tensor(8.4644)

# %% [markdown]
# ## 4. Step-by-step breakdown

# %% [markdown]
# *   Exercise 1 checks the model function after training.
#
# *   Exercise 2 separates evaluation from updating. `detach()` gives values without tracking gradients.
#
# *   This separation helps debug whether prediction and loss work before training changes anything.

# %% [markdown]
# ## 5. Connection to ML systems

# %% [markdown]
# *   Evaluation code should usually avoid building gradient graphs because it does not update parameters.

# %% [markdown]
# ## 6. Common confusion points

# %% [markdown]
# - `detach()` stops gradient tracking for that value.
# - Evaluation loss is not a parameter update.
# - A single batch loss is noisy.
# - Always know whether your code is training or only measuring.
